# %% [markdown]
# # Matplotlib Assignment Questions

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of Matplotlib.

# %% [markdown]
# Matplotlib is a powerful data visualization library in Python. It creates a variety of plots such as line plots, scatter plots and many more. It is built on NumPy arrays and designed to work with the broader SciPy stack.
#
# Matplotlib is a cross-platform library. It can be used in Python scripts, IPython shells, the Jupyter notebook, web application servers, and four GUI tools.
#
# Here are five Matplotlib plots:
#
# * Line Plot
#
# * Scatter Plot
#
# * Histogram Plot
#
# * Bar Chart Plot
#
# * Pie Chart Plot

# %% [markdown]
# ### Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data plot a scatter plot.

# %% [markdown]
# A scatter plot is a type of graph that displays the values of two variables in a set of data using Cartesian coordinates.

# %%
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# Note: Also add title, xlabel, and ylabel to the plot.

# %%
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Scatter Plot')
plt.scatter(x, y)
plt.show()

# %% [markdown]
# ### Q3: Why is the subplot() function used? Draw four line plots using the subplot() function. Use the following data:
#
# * For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
# * For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
# * For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
# * For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %% [markdown]
# The subplot() function creates multiple subplot layouts in a single figure. With it, I can create common subplot layouts, including enclosed figures.

# %%
x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])

x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])

x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])

x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])

plt.subplot(2 ,2 ,1)
plt.plot(x1,y1)

plt.subplot(2 ,2 ,2)
plt.plot(x2,y2)

plt.subplot(2 ,2 ,3)
plt.plot(x3,y3)

plt.subplot(2 ,2 ,4)
plt.plot(x4,y4)

plt.show()

# %% [markdown]
# ### Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.

# %%
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# %% [markdown]
# Bar plots are common graphics used to show the relationship between a numerical and a categorical variable. It represents categorical data that can be divided into distinct categories.

# %%
plt.xlabel('Company')
plt.ylabel('Profit')
plt.title('Company Profit Bar')
plt.bar(company, profit)
plt.show()

# %%
plt.xlabel('Profit')
plt.ylabel('Company')
plt.title('Company Profit Bar')
plt.barh(company, profit)

plt.show()

# %% [markdown]
# ### Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
# * box1 = np.random.normal(100, 10, 200)
# * box2 = np.random.normal(90, 20, 200)

# %% [markdown]
# Box plots are charts that show numerical data distribution and its variance. I can see the minimum, maximum, median, and quartiles of a data set.

# %% [markdown]
# I can use box plots to compare data between groups, show variability or dispersion, or spot outliers.

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

data = [box1, box2]

plt.title('Box plot')
plt.boxplot(data)

plt.show()
