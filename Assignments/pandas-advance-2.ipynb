# %% [markdown]
# # Pandas Advance-2 Assignment Questions

# %%
import pandas as pd

# %%
# Consider following code to answer further questions: 

import pandas as pd
course_name = ['Data Science', 'Machine Learning', 'Big Data', 'Data Engineer']
duration = [2,3,6,4]
df = pd.DataFrame(data = {'course_name' : course_name, 'duration' : duration})

# %%
df
# Out:
#         course_name  duration
# 0      Data Science         2
# 1  Machine Learning         3
# 2          Big Data         6
# 3     Data Engineer         4

# %% [markdown]
# ### Q1. Write a code to print the data present in the second row of the dataframe, df.

# %%
df.iloc[1]
# Out:
# course_name    Machine Learning
# duration                      3
# Name: 1, dtype: object

# %% [markdown]
# ### Q2. What is the difference between the functions loc and iloc in pandas.DataFrame?

# %% [markdown]
# In Pandas, iloc is an index-based selection function and loc is a label-based selection function. Selecting data using the loc operator is more efficient than selecting data using indexes based on their numerical positions.

# %% [markdown]
# ### Q3. Reindex the given dataframe using a variable, `reindex = [3,0,1,2]` and store it in the variable, `new_df` then find the output for both `new_df.loc[2]` and `new_df.iloc[2]`.

# %%
new_df = df.reindex([3,0,1,2])

# %%
new_df
# Out:
#         course_name  duration
# 3     Data Engineer         4
# 0      Data Science         2
# 1  Machine Learning         3
# 2          Big Data         6

# %%
new_df.loc[2]
# Out:
# course_name    Big Data
# duration              6
# Name: 2, dtype: object

# %%
new_df.iloc[2]
# Out:
# course_name    Machine Learning
# duration                      3
# Name: 1, dtype: object

# %% [markdown]
# Yes, there is a difference between the outputs of `new_df.loc[2]` and `new_df.iloc[2]`. `new_df.loc[2]` contains the data for the row at index label 2, and `new_df.iloc[2]` contains the data for the row at numerical index 2 in new_df.

# %% [markdown]
# ### Consider the below code to answer further questions:

# %%
import pandas as pd
import numpy as np
columns = ['column_1', 'column_2', 'column_3', 'column_4', 'column_5', 'column_6']
indices = [1,2,3,4,5,6]

df1 = pd.DataFrame(np.random.rand(6,6), columns = columns, index = indices)

# %%
df1
# Out:
#    column_1  column_2  column_3  column_4  column_5  column_6
# 1  0.146205  0.273528  0.856006  0.647062  0.040153  0.622187
# 2  0.487594  0.277812  0.045739  0.581441  0.361863  0.163726
# 3  0.689330  0.493837  0.732792  0.057444  0.341199  0.003568
# 4  0.804582  0.267604  0.786594  0.788212  0.974624  0.411316
# 5  0.718097  0.543183  0.321556  0.136986  0.668453  0.027002
# 6  0.272942  0.298943  0.837795  0.740977  0.790933  0.880378

# %% [markdown]
# ### Q4. Write a code to find the following statistical measurements for the above dataframe df1:
# * (i) mean of each and every column present in the dataframe.
# * (ii) standard deviation of column, ‘column_2’

# %%
df1.mean()
# Out:
# column_1    0.519792
# column_2    0.359151
# column_3    0.596747
# column_4    0.492021
# column_5    0.529537
# column_6    0.351363
# dtype: float64

# %%
df1[['column_2']].std()
# Out:
# column_2    0.124869
# dtype: float64

# %% [markdown]
# ### Q5. Replace the data present in the second row of column, ‘column_2’ by a string variable then find the mean of column, column_2. If you are getting errors in executing it then explain why.

# %%
df1['column_2']
# Out:
# 1    0.273528
# 2    0.277812
# 3    0.493837
# 4    0.267604
# 5    0.543183
# 6    0.298943
# Name: column_2, dtype: float64

# %%
df1['column_2'].loc[1] = "hello"

# %%
df1['column_2'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df1['column_2'].mean()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/generic.py:11847, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11829 @doc(
#   11830     _num_doc,
#   11831     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11845     **kwargs,
#   11846 ):
# > 11847     return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/generic.py:11401, in NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11393 def mean(
#   11394     self,
#   11395     axis: Axis | None | lib.NoDefault = lib.no_default,
#    (...)
#   11399     **kwargs,
#   11400 ) -> Series | float:
# > 11401     return self._stat_function(
# ...

# %% [markdown]
# The `mean()` function calculates the mean of numerical values in a column. If the column contains non-numeric values, such as strings or a combination of strings and numbers, it will result in a `TypeError` when calculating the mean.

# %% [markdown]
# ### Q6. What do you understand about the windows function in pandas and list the types of windows functions?

# %% [markdown]
# In Pandas, the window functions are used for calculations on a sliding window of data. These functions allow us to compute aggregations, transformations, or other operations on a specific window of data within a larger dataset.
#
# Pandas offers several types of window functions. Some commonly used window functions include:
#
# * Rolling Window Functions
#
# * Expanding Window Functions
#
# * Exponential Weighted Functions
#
# * Time-based Window Functions

# %% [markdown]
# ### Q7. Write a code to print only the current month and year at the time of answering this question.

# %%
today = pd.Timestamp.now()

# %%
today.month
# Out:
# 7

# %%
today.year
# Out:
# 2023

# %% [markdown]
# ### Q8. Write a Python program that takes in two dates as input (in the format YYYY-MM-DD) and calculates the difference between them in days, hours, and minutes using Pandas time delta. The program should prompt the user to enter the dates and display the result.

# %%
def get_dates(date1, date2):
    dt = (pd.to_datetime(date1) - pd.to_datetime(date2))
    day = dt.total_seconds() / 60 / 60 / 24
    hour = dt.total_seconds() / 60 / 60
    minute = dt.total_seconds() / 60
    
    return f"The difference between the two dates is {day:.0f} days, {hour:.0f} hours, and {minute:.0f} minutes."

date1 = input("Enter the first date (YYYY-MM-DD): ")
date2 = input("Enter the second date (YYYY-MM-DD): ")
get_dates(date1, date2)
# Out:
# Enter the first date (YYYY-MM-DD):  2023-03-01
# Enter the second date (YYYY-MM-DD):  2023-01-23
# 'The difference between the two dates is 37 days, 888 hours, and 53280 minutes.'

# %% [markdown]
# ### Q9. Write a Python program that reads a CSV file containing categorical data and converts a specified column to a categorical data type. The program should prompt the user to enter the file path, column name, and category order, and then display the sorted data.

# %%
def categorical_data(file_path, column, order):
    df = pd.read_csv(file_path)
    df[column] = pd.Categorical(df[column], categories=order)
    df.sort_values(column)
    return df
    
file_path = input("Enter file path: ")
column = input("Enter column name: ")
order = input("Enter category order: ").split(",")
categorical_data(file_path, column, order)
# Out:
# Enter file path:  /kaggle/input/datacsv1/data.csv
# Enter column name:  Occupation
# Enter category order:  Engineer,Teacher,Doctor,Lawyer
#       Name  Age  Gender Occupation
# 0    Alice   25  Female   Engineer
# 1      Bob   32    Male    Teacher
# 2  Charlie   40    Male     Doctor
# 3     Dave   23    Male        NaN
# 4      Eve   30  Female     Lawyer

# %% [markdown]
# ### Q10. Write a Python program that reads a CSV file containing sales data for different products and visualizes the data using a stacked bar chart to show the sales of each product category over time. The program should prompt the user to enter the file path and display the chart.

# %%
def stacked_bar(file_path):
    df = pd.read_csv(file_path)
    sum_of_sales = df.groupby('product')['quantity'].sum()
    return sum_of_sales.plot(kind='bar', stacked=True)
    
file_path = input("Enter the file path: ")
stacked_bar(file_path)
# Out:
# Enter the file path:  /kaggle/input/salesdf/sales.csv
# <Axes: xlabel='product'>

# %% [markdown]
# ### Q11. You are given a CSV file containing student data that includes the student ID and their test score. Write a Python program that reads the CSV file, calculates the mean, median, and mode of the test scores, and displays the results in a table.

# %%
def student_data(file_path):
    df = pd.read_csv(file_path)
    mean = df['score'].mean()
    median = df['score'].median()
    mode = df['score'].mode().tolist()
    
    return mean, median, mode

file_path = input("Enter your file path: ")
student_data(file_path)
# Out:
# Enter your file path:  /kaggle/input/students/students.csv
# (85.4, 86.5, [75, 78, 80, 82, 85, 88, 89, 90, 92, 95])
