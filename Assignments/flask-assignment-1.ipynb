# %% [markdown]
# # Flask Assignment

# %% [markdown]
# ### Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# Flask is a micro-framework for web development in Python.
#
# #### Advantages:
#
# * Flask can be used for a wide range of projects.
# * It is an open-source framework and free to use.
# * It is a popular framework and it is easy to find developers familiar with it.
# * It has built-in security features to protect web applications.
# * It is flexible and can be easily extended with additional functionality.
# * It can be used in small and large-scale applications.

# %% [markdown]
# ### Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook.

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/")
def home():
    return "Hello, World!"

if __name__=="__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ![Screenshot from 2023-06-22 14-32-14.png](attachment:36cfd499-c695-4617-b5b8-ddc3034d0a48.png)

# %% [markdown]
# ### Q3. What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# In Flask, app routing refers to mapping URLs to a function that handles that URL's logic. Using meaningful URLs helps users remember URLs and makes navigation easier.
#
# For example, the URL ("/") refers to the root URL. If our site's domain is example.org, we would use "/hello" to add routing to "example.org/hello".

# %% [markdown]
# ### Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/” route to show the following details:
# * Company Name: ABC Corporation
# * Location: India
# * Contact Detail: 999-999-9999

# %%
from flask import Flask

app = Flask(__name__)

@app.route("/")
def home():
    return 'Company Name: ABC Corporation<br>Location: India<br>Contact Detail: 999-999-9999'

@app.route('/welcome')
def welcome():
    return "Welcome to ABC Corporation"


if __name__=="__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# #### Welcome ('/welcome') route

# %% [markdown]
# ![Screenshot from 2023-06-22 14-59-59.png](attachment:9e9a870d-e65a-4da7-a43b-ff6e7565f477.png)

# %% [markdown]
# #### Home ('/') route

# %% [markdown]
# ![Screenshot from 2023-06-22 14-59-39.png](attachment:99c354ba-a5ab-45dc-ab2c-348b6480f1d4.png)

# %% [markdown]
# ### Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.

# %% [markdown]
# Flask uses the url_for() function for URL building. This prevents the app from changing URLs when a specific function is called. In the first argument, it takes the name of the view function, and in the second argument, any number of keywords.

# %%
from flask import Flask, url_for
app = Flask(__name__)

@app.route('/')
def index():
    return 'Index Page'

@app.route('/hello')
def hello():
    return 'Hello World!'

with app.test_request_context():
    print(url_for('index'))
    print(url_for('hello'))
# Out:
# /
# /hello
